# %% [markdown]
# # Mohammed Al Mujadib
#
#
# # Project : Wrangle and Analyze Data
#
#
# ## Table of Contents:
# - [Gathering](#Gathering)
# - [Assessing](#Assessing)
# - [Cleaning](#Gathering)
# - [Analysis](#Analysis)

# %%
import pandas as pd
import numpy as np
import requests
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a id='Gathering'></a>
# ## 1-Gathering:

# %% [markdown]
# **Read twitter archive File:**

# %%
df_twitter = pd.read_csv('twitter-archive-enhanced-2.csv')
df_twitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# **Fetch and read TSV file:**

# %%
req = requests.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv')

# %%
import os
with open ('image-predictions-3.tsv', 'wb') as file:
    file.write(req.content)

# %%
df_image_predictions = pd.read_csv('image_predictions-3.tsv', sep = '\t')
df_image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# **Twitter API & JSON:**

# %%
consumer_key = 'Hidden'
consumer_secret = 'Hidden'
access_token = 'Hidden'
access_secret = 'Hidden'



# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions


auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_twitter.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %% [markdown]
# **Store data in Dataframes:**

# %%
df_list = []
with open('tweet-json.txt', 'r', encoding='utf8') as api:
    for line in api:
        tweet_line = json.loads(line)
        df_list.append({'Tweet_id': tweet_line['id'],
                        'Likes': tweet_line['favorite_count'],
                        'RT': tweet_line['retweet_count']})
df_API = pd.DataFrame(df_list)
df_API.head(2)
# Out:
#              Tweet_id  Likes    RT
# 0  892420643555336193  39467  8853
# 1  892177421306343426  33819  6514

# %% [markdown]
# <a id='Assessing'></a>
# ## 2-Assessing:

# %% [markdown]
# **Visual assessment:**

# %%
df_twitter
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
df_image_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
df_API
# Out:
#                 Tweet_id  Likes    RT
# 0     892420643555336193  39467  8853
# 1     892177421306343426  33819  6514
# 2     891815181378084864  25461  4328
# 3     891689557279858688  42908  8964
# 4     891327558926688256  41048  9774
# ...                  ...    ...   ...
# 2349  666049248165822465    111    41
# 2350  666044226329800704    311   147
# 2351  666033412701032449    128    47
# 2352  666029285002620928    132    48
# 2353  666020888022790149   2535   532
#
# [2354 rows x 3 columns]

# %% [markdown]
# **Programmatic Assessment:**

# %%
df_twitter.head(10)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
# 5  891087950875897856                    NaN                  NaN
# 6  890971913173991426                    NaN                  NaN
# 7  890729181411237888                    NaN                  NaN
# 8  890609185150312448                    NaN                  NaN
# 9  890240255349198849                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
# 5  2017-07-29 00:08:17 +0000
# ...

# %%
df_twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
df_twitter.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df_twitter.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 715   783839966405230592                    NaN                  NaN
# 566   802247111496568832                    NaN                  NaN
# 2114  670433248821026816                    NaN                  NaN
# 1606  685667379192414208                    NaN                  NaN
# 1305  707387676719185920                    NaN                  NaN
# 706   785533386513321988                    NaN                  NaN
# 1671  682393905736888321                    NaN                  NaN
# 904   758355060040593408                    NaN                  NaN
# 1757  678764513869611008                    NaN                  NaN
# 1530  690021994562220032                    NaN                  NaN
#
#                       timestamp  \
# 715   2016-10-06 01:23:05 +0000
# 566   2016-11-25 20:26:31 +0000
# 2114  2015-11-28 02:45:17 +0000
# 1606  2016-01-09 03:40:16 +0000
# 1305  2016-03-09 02:08:59 +0000
# ...

# %%
df_twitter.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Cooper      11
# Oliver      11
#           ...
# Marlee       1
# his          1
# Coopson      1
# Teddy        1
# Bayley       1
# Name: name, Length: 957, dtype: int64

# %%
df_twitter.query("name == 'a'")
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %%
df_twitter.query("name == 'Cooper'")
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 124   868639477480148993                    NaN                  NaN
# 126   868552278524837888                    NaN                  NaN
# 483   814986499976527872                    NaN                  NaN
# 532   808001312164028416                    NaN                  NaN
# 607   798209839306514432                    NaN                  NaN
# 910   757611664640446465                    NaN                  NaN
# 961   751132876104687617                    NaN                  NaN
# 1291  708119489313951744                    NaN                  NaN
# 1333  705442520700944385                    NaN                  NaN
# 1395  699801817392291840                    NaN                  NaN
# 1800  676975532580409345                    NaN                  NaN
#
#                       timestamp  \
# 124   2017-05-28 01:26:04 +0000
# 126   2017-05-27 19:39:34 +0000
# 483   2016-12-31 00:08:17 +0000
# ...

# %%
df_twitter.query("name == 'this'")
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1120  731156023742988288                    NaN                  NaN
#
#                       timestamp  \
# 1120  2016-05-13 16:15:54 +0000
#
#                                                  source  \
# 1120  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1120  Say hello to this unbelievably well behaved sq...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1120                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1120  https://twitter.com/dog_rates/status/731156023...               204
#
#       rating_denominator  name doggo floofer pupper puppo
# 1120                 170  this  None    None   None  None

# %%
df_twitter.query("rating_denominator > 10")
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1433  697463031882764288                    NaN                  NaN
# ...

# %%
df_twitter.round(4)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# **number of missing values in expanded_urls column:**

# %%
sum(df_twitter.expanded_urls.isnull())
# Out:
# 59

# %%
df_image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df_image_predictions.sample(10)
# Out:
#                 tweet_id                                            jpg_url  \
# 1343  759047813560868866    https://pbs.twimg.com/media/Coit84_VYAEMtLi.jpg
# 1230  745712589599014916    https://pbs.twimg.com/media/CllNnkWWMAEDIAR.jpg
# 791   690690673629138944    https://pbs.twimg.com/media/CZXTgKkWwAA5UZJ.jpg
# 1828  835574547218894849    https://pbs.twimg.com/media/C5iOnigWcAAU3Ry.jpg
# 462   674805413498527744  https://pbs.twimg.com/ext_tw_video_thumb/67480...
# 43    666776908487630848    https://pbs.twimg.com/media/CUDeDoWUYAAD-EM.jpg
# 388   673355879178194945    https://pbs.twimg.com/media/CVg9mTYWIAAu7J6.jpg
# 987   707741517457260545    https://pbs.twimg.com/media/CdJnJ1dUEAARNcf.jpg
# 1803  832040443403784192    https://pbs.twimg.com/media/Cq9guJ5WgAADfpF.jpg
# 1899  851224888060895234    https://pbs.twimg.com/media/C9AohFoWsAUmxDs.jpg
#
#       img_num                         p1   p1_conf  p1_dog  \
# 1343        1         Labrador_retriever  0.778546    True
# ...

# %%
df_image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df_image_predictions.round(4)
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1  p1_conf  p1_dog                  p2  \
# ...

# %%
df_image_predictions.jpg_url.value_counts()
# Out:
# https://pbs.twimg.com/media/CtzKC7zXEAALfSo.jpg    2
# https://pbs.twimg.com/media/Cx5R8wPVEAALa9r.jpg    2
# https://pbs.twimg.com/media/C4bTH6nWMAAX_bJ.jpg    2
# https://pbs.twimg.com/media/Ct72q9jWcAAhlnw.jpg    2
# https://pbs.twimg.com/media/CvaYgDOWgAEfjls.jpg    2
#                                                   ..
# https://pbs.twimg.com/media/CWskEqnWUAAQZW_.jpg    1
# https://pbs.twimg.com/media/CiI7zVZUoAEzGW7.jpg    1
# https://pbs.twimg.com/media/CVRVvRMWEAIBKOP.jpg    1
# https://pbs.twimg.com/media/CUYrBNQUkAA-zx4.jpg    1
# https://pbs.twimg.com/media/Cd8Rpl0W0AAN1kU.jpg    1
# Name: jpg_url, Length: 2009, dtype: int64

# %%
df_image_predictions.query('jpg_url == "https://pbs.twimg.com/media/Crwxb5yWgAAX5P_.jpg"')
# Out:
#                 tweet_id                                          jpg_url  \
# 1433  773547596996571136  https://pbs.twimg.com/media/Crwxb5yWgAAX5P_.jpg
# 1712  818588835076603904  https://pbs.twimg.com/media/Crwxb5yWgAAX5P_.jpg
#
#       img_num                  p1   p1_conf  p1_dog                        p2  \
# 1433        1  Norwegian_elkhound  0.372202    True  Chesapeake_Bay_retriever
# 1712        1  Norwegian_elkhound  0.372202    True  Chesapeake_Bay_retriever
#
#        p2_conf  p2_dog        p3   p3_conf  p3_dog
# 1433  0.137187    True  malamute  0.071436    True
# 1712  0.137187    True  malamute  0.071436    True

# %%
df_image_predictions.query('jpg_url == "https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg"')
# Out:
#                 tweet_id                                          jpg_url  \
# 1188  739544079319588864  https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# 1349  759566828574212096  https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
#
#       img_num                  p1   p1_conf  p1_dog                p2  \
# 1188        1  Labrador_retriever  0.967397    True  golden_retriever
# 1349        1  Labrador_retriever  0.967397    True  golden_retriever
#
#        p2_conf  p2_dog        p3   p3_conf  p3_dog
# 1188  0.016641    True  ice_bear  0.014858   False
# 1349  0.016641    True  ice_bear  0.014858   False

# %%
df_API.head(10)
# Out:
#              Tweet_id  Likes     RT
# 0  892420643555336193  39467   8853
# 1  892177421306343426  33819   6514
# 2  891815181378084864  25461   4328
# 3  891689557279858688  42908   8964
# 4  891327558926688256  41048   9774
# 5  891087950875897856  20562   3261
# 6  890971913173991426  12041   2158
# 7  890729181411237888  56848  16716
# 8  890609185150312448  28226   4429
# 9  890240255349198849  32467   7711

# %%
df_API.sample(10)
# Out:
#                 Tweet_id  Likes    RT
# 2317  666447344410484738    107    23
# 1303  707387676719185920   3835  1490
# 1095  736225175608430592   8901  3115
# 2195  668826086256599040    467   150
# 1681  681694085539872773  14010  4581
# 1003  747651430853525504   1520   179
# 31    886054160059072513      0   108
# 4     891327558926688256  41048  9774
# 2256  667724302356258817    517   341
# 2203  668633411083464705   3024  1788

# %%
df_API.describe()
# Out:
#            Tweet_id          Likes            RT
# count  2.354000e+03    2354.000000   2354.000000
# mean   7.426978e+17    8080.968564   3164.797366
# std    6.852812e+16   11814.771334   5284.770364
# min    6.660209e+17       0.000000      0.000000
# 25%    6.783975e+17    1415.000000    624.500000
# 50%    7.194596e+17    3603.500000   1473.500000
# 75%    7.993058e+17   10122.250000   3652.000000
# max    8.924206e+17  132810.000000  79515.000000

# %%
df_API.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet_id  2354 non-null   int64
#  1   Likes     2354 non-null   int64
#  2   RT        2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %% [markdown]
# ### Quality Issues:
#
# **1-There is (59) row that does not have expanded_url, and they are not useful so.**
#
# **2-img_num column should be converted to category date type in Image Prediction Dataset.**
#
# **3-There are too many duplicate tweet (818588835076603904) & (773547596996571136), (739544079319588864) & (759566828574212096)in Image Prediction Dataset.**
#
# **4-In twitter archive dataset we should remove the (a) tag and make the column contain the (URL) for the source of tweet only.**
#
# **5-There are (55) dog who have no name and their name recorded as letter (a) in twitter archive dataset.
# 6-Timestamp should be converted to datetime.**
#
# **7-The names and type that is unavailable should be (null).**
#
# **8-There are an issue in tweet ID (731156023742988288) because in the dataset their name is recorded as (this) but the actual tweet did not mention any name of the dogs, and in the tweet ID (748575535303884801) the dog has no name in the tweet and it recorded as (one).**

# %% [markdown]
# ## Tidiness Issues:
#
# **1-In twitter archive dataset we should have one column instead of having four columns for each type and we should call that column is (type).**
#
# **2-Create master dataframe that merge all the dataframes togther.**
#
# **3-In twitter archive dataset we should create new column called (Rating) instead of two column, and that column will be created based on the (rating_numerator) column & (rating_denominator) column**

# %% [markdown]
# <a id='Cleaning'></a>
# ## 3- Cleaning:
#
# **Copies of the original files to clean:**

# %%
df_archives = df_twitter.copy()
df_img = df_image_predictions.copy()
df_api = df_API.copy()

# %% [markdown]
# **Define:**
#
# **droping the missing value of expanded_urls column:**
#
# **code:**

# %%
df_archives.dropna(subset = ['expanded_urls'] , inplace = True)

# %% [markdown]
# **Test:**

# %%
sum(df_archives.expanded_urls.isnull())
# Out:
# 0

# %% [markdown]
# **Define:**
#
# **Convert timestamp data type from string to datetime:**
#
# **Code:**

# %%
df_archives.timestamp =  pd.to_datetime(df_archives['timestamp'])

# %% [markdown]
# **Test:**

# %%
df_archives.dtypes
# Out:
# tweet_id                                    int64
# in_reply_to_status_id                     float64
# in_reply_to_user_id                       float64
# timestamp                     datetime64[ns, UTC]
# source                                     object
# text                                       object
# retweeted_status_id                       float64
# retweeted_status_user_id                  float64
# retweeted_status_timestamp                 object
# expanded_urls                              object
# rating_numerator                            int64
# rating_denominator                          int64
# name                                       object
# doggo                                      object
# floofer                                    object
# pupper                                     object
# puppo                                      object
# dtype: object

# %% [markdown]
# **Define:**
#
# **Remove the Anchor tag from the source column:**
#
# **Code:**

# %%
import re
df_archives.source = df_archives.source.apply(lambda x: re.sub('<[^<]+?>', '', x))

# %% [markdown]
# **Test:**

# %%
df_archives.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 503   813066809284972545                    NaN                  NaN
# 1146  727155742655025152                    NaN                  NaN
# 390   826240494070030336                    NaN                  NaN
# 246   845677943972139009                    NaN                  NaN
# 618   796177847564038144                    NaN                  NaN
# 549   805207613751304193                    NaN                  NaN
# 1500  692158366030913536                    NaN                  NaN
# 56    881536004380872706                    NaN                  NaN
# 1824  676496375194980353                    NaN                  NaN
# 69    879050749262655488                    NaN                  NaN
#
#                      timestamp               source  \
# 503  2016-12-25 17:00:08+00:00   Twitter for iPhone
# 1146 2016-05-02 15:20:13+00:00  Vine - Make a Scene
# ...

# %% [markdown]
# **Define:**
#
# **Reaplace dog name "a" to "None":**
#
# **Code:**

# %%
df_archives.name = df_archives.name.str.replace('a', 'None')

# %% [markdown]
# **Test:**

# %%
df_archives.query("name == 'a'")
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# **Define:**
#
# **There are duplicate tweet with tweet ID (868552278524837888) & (868639477480148993) and we will drop one of them:**
#
# **Code:**

# %%
df_archives.query('tweet_id == 868552278524837888 or tweet_id == 868639477480148993')
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 124  868639477480148993                    NaN                  NaN
# 126  868552278524837888                    NaN                  NaN
#
#                     timestamp              source  \
# 124 2017-05-28 01:26:04+00:00  Twitter for iPhone
# 126 2017-05-27 19:39:34+00:00  Twitter for iPhone
#
#                                                   text  retweeted_status_id  \
# 124  RT @dog_rates: Say hello to Cooper. His expres...         8.685523e+17
# 126  Say hello to Cooper. His expression is the sam...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 124              4.196984e+09  2017-05-27 19:39:34 +0000
# 126                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 124  https://www.gofundme.com/3ti3nps,https://twitt...                12
# ...

# %%
df_archives = df_archives[df_archives['tweet_id'] != 868639477480148993]

# %% [markdown]
# **Test:**

# %%
df_archives.query('tweet_id == 868639477480148993')
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# **Define:**
#
# **Replace the rating_numerator from (9) to (14) & rating_denominator from (11) to (10) with the tweet ID (740373189193256964), we could use loc function:**
#
# **Code:**

# %%
df_archives.query('tweet_id == 740373189193256964')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1068  740373189193256964                    NaN                  NaN
#
#                      timestamp              source  \
# 1068 2016-06-08 02:41:38+00:00  Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 1068  After so many requests, this is Bretagne. She ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1068                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1068  https://twitter.com/dog_rates/status/740373189...                 9
#
#       rating_denominator  name doggo floofer pupper puppo
# 1068                  11  None  None    None   None  None

# %%
df_archives.loc[df_archives['tweet_id'] == 740373189193256964, 'rating_numerator'] = 14
df_archives.loc[df_archives['tweet_id'] == 740373189193256964, 'rating_denominator'] = 10

# %% [markdown]
# **Test:**

# %%
df_archives.query('tweet_id == 740373189193256964')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1068  740373189193256964                    NaN                  NaN
#
#                      timestamp              source  \
# 1068 2016-06-08 02:41:38+00:00  Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 1068  After so many requests, this is Bretagne. She ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1068                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1068  https://twitter.com/dog_rates/status/740373189...                14
#
#       rating_denominator  name doggo floofer pupper puppo
# 1068                  10  None  None    None   None  None

# %% [markdown]
# **Define:**
#
# **Replace the rating_numerator from (4) to (13) & rating_denominator from (20) to (10) with the tweet ID (722974582966214656), we could use loc function:**
#
# **Code:**

# %%
df_archives.query('tweet_id == 722974582966214656')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1165  722974582966214656                    NaN                  NaN
#
#                      timestamp              source  \
# 1165 2016-04-21 02:25:47+00:00  Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 1165  Happy 4/20 from the squad! 13/10 for all https...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1165                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1165  https://twitter.com/dog_rates/status/722974582...                 4
#
#       rating_denominator  name doggo floofer pupper puppo
# 1165                  20  None  None    None   None  None

# %%
df_archives.loc[df_archives['tweet_id'] == 722974582966214656, 'rating_numerator'] = 13
df_archives.loc[df_archives['tweet_id'] == 722974582966214656, 'rating_denominator'] = 10

# %% [markdown]
# **Test:**

# %%
df_archives.query('tweet_id == 722974582966214656')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1165  722974582966214656                    NaN                  NaN
#
#                      timestamp              source  \
# 1165 2016-04-21 02:25:47+00:00  Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 1165  Happy 4/20 from the squad! 13/10 for all https...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1165                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1165  https://twitter.com/dog_rates/status/722974582...                13
#
#       rating_denominator  name doggo floofer pupper puppo
# 1165                  10  None  None    None   None  None

# %%
df_archives.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp              source  \
# 0 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# ...

# %% [markdown]
# **Define:**
#
#
# **Name issue in Tweet ID (731156023742988288) & Tweet ID (748575535303884801)**
#
#
# **Code:**

# %%
df_archives.query('tweet_id == 731156023742988288')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1120  731156023742988288                    NaN                  NaN
#
#                      timestamp              source  \
# 1120 2016-05-13 16:15:54+00:00  Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 1120  Say hello to this unbelievably well behaved sq...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1120                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1120  https://twitter.com/dog_rates/status/731156023...               204
#
#       rating_denominator  name doggo floofer pupper puppo
# 1120                 170  this  None    None   None  None

# %%
df_archives.query('tweet_id == 748575535303884801')
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 993  748575535303884801                    NaN                  NaN
#
#                     timestamp              source  \
# 993 2016-06-30 17:54:50+00:00  Twitter for iPhone
#
#                                                   text  retweeted_status_id  \
# 993  This is one of the most reckless puppers I've ...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 993                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 993  https://twitter.com/dog_rates/status/748575535...                 6
#
#      rating_denominator name doggo floofer pupper puppo
# 993                  10  one  None    None   None  None

# %%
df_archives.name = df_archives.name.replace('this' , 'None')
df_archives.name = df_archives.name.replace('one' , 'None')

# %% [markdown]
# **Test:**

# %%
df_archives.query('tweet_id == 731156023742988288')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1120  731156023742988288                    NaN                  NaN
#
#                      timestamp              source  \
# 1120 2016-05-13 16:15:54+00:00  Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 1120  Say hello to this unbelievably well behaved sq...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1120                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1120  https://twitter.com/dog_rates/status/731156023...               204
#
#       rating_denominator  name doggo floofer pupper puppo
# 1120                 170  None  None    None   None  None

# %%
df_archives.query('tweet_id == 748575535303884801')
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 993  748575535303884801                    NaN                  NaN
#
#                     timestamp              source  \
# 993 2016-06-30 17:54:50+00:00  Twitter for iPhone
#
#                                                   text  retweeted_status_id  \
# 993  This is one of the most reckless puppers I've ...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 993                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 993  https://twitter.com/dog_rates/status/748575535...                 6
#
#      rating_denominator  name doggo floofer pupper puppo
# 993                  10  None  None    None   None  None

# %% [markdown]
# **Define:**
#
# **Replace names and type that is unavailable to (null):**
#
# **Code:**

# %%
df_archives = df_archives.replace('None',np.NaN)

# %% [markdown]
# **Test:**

# %%
df_archives.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 511   811985624773361665                    NaN                  NaN
# 2173  669324657376567296                    NaN                  NaN
# 937   753298634498793472                    NaN                  NaN
# 651   792773781206999040                    NaN                  NaN
# 1904  674632714662858753                    NaN                  NaN
# 2118  670420569653809152                    NaN                  NaN
# 2194  668892474547511297                    NaN                  NaN
# 2320  666437273139982337                    NaN                  NaN
# 639   793256262322548741                    NaN                  NaN
# 2217  668528771708952576                    NaN                  NaN
#
#                      timestamp              source  \
# 511  2016-12-22 17:23:53+00:00  Twitter for iPhone
# 2173 2015-11-25 01:20:08+00:00  Twitter for iPhone
# ...

# %% [markdown]
# **Define:**
#
# **Change Source Column to category data type:**
#
# **Code:**

# %%
df_archives.source = df_archives.source.astype('category')

# %% [markdown]
# **Test:**

# %%
df_archives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2296 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2296 non-null   int64
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   2296 non-null   datetime64[ns, UTC]
#  4   source                      2296 non-null   category
#  5   text                        2296 non-null   object
#  6   retweeted_status_id         179 non-null    float64
#  7   retweeted_status_user_id    179 non-null    float64
#  8   retweeted_status_timestamp  179 non-null    object
#  9   expanded_urls               2296 non-null   object
#  10  rating_numerator            2296 non-null   int64
#  11  rating_denominator          2296 non-null   int64
#  12  name                        1550 non-null   object
# ...

# %%
df_archives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2296 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2296 non-null   int64
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   2296 non-null   datetime64[ns, UTC]
#  4   source                      2296 non-null   category
#  5   text                        2296 non-null   object
#  6   retweeted_status_id         179 non-null    float64
#  7   retweeted_status_user_id    179 non-null    float64
#  8   retweeted_status_timestamp  179 non-null    object
#  9   expanded_urls               2296 non-null   object
#  10  rating_numerator            2296 non-null   int64
#  11  rating_denominator          2296 non-null   int64
#  12  name                        1550 non-null   object
# ...

# %% [markdown]
# **Define:**
#
# **Duplicate tweets with tweet ID (818588835076603904) & (773547596996571136), (739544079319588864) & (759566828574212096)**
#
# **Code:**

# %%
df_img.query("tweet_id == 818588835076603904 or tweet_id == 773547596996571136 or tweet_id == 739544079319588864 or tweet_id == 759566828574212096")
# Out:
#                 tweet_id                                          jpg_url  \
# 1188  739544079319588864  https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# 1349  759566828574212096  https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# 1433  773547596996571136  https://pbs.twimg.com/media/Crwxb5yWgAAX5P_.jpg
# 1712  818588835076603904  https://pbs.twimg.com/media/Crwxb5yWgAAX5P_.jpg
#
#       img_num                  p1   p1_conf  p1_dog                        p2  \
# 1188        1  Labrador_retriever  0.967397    True          golden_retriever
# 1349        1  Labrador_retriever  0.967397    True          golden_retriever
# 1433        1  Norwegian_elkhound  0.372202    True  Chesapeake_Bay_retriever
# 1712        1  Norwegian_elkhound  0.372202    True  Chesapeake_Bay_retriever
#
#        p2_conf  p2_dog        p3   p3_conf  p3_dog
# 1188  0.016641    True  ice_bear  0.014858   False
# 1349  0.016641    True  ice_bear  0.014858   False
# ...

# %%
df_img = df_img[df_img['tweet_id'] != 818588835076603904]
df_img = df_img[df_img['tweet_id'] != 739544079319588864]

# %% [markdown]
# **Test:**

# %%
df_img.query("tweet_id == 818588835076603904 or tweet_id == 773547596996571136 or tweet_id == 739544079319588864 or tweet_id == 759566828574212096")
# Out:
#                 tweet_id                                          jpg_url  \
# 1349  759566828574212096  https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# 1433  773547596996571136  https://pbs.twimg.com/media/Crwxb5yWgAAX5P_.jpg
#
#       img_num                  p1   p1_conf  p1_dog                        p2  \
# 1349        1  Labrador_retriever  0.967397    True          golden_retriever
# 1433        1  Norwegian_elkhound  0.372202    True  Chesapeake_Bay_retriever
#
#        p2_conf  p2_dog        p3   p3_conf  p3_dog
# 1349  0.016641    True  ice_bear  0.014858   False
# 1433  0.137187    True  malamute  0.071436    True

# %% [markdown]
# **Define:**
#
# **Change img_num column to category data type**
#
# **Code:**

# %%
df_img.img_num = df_img.img_num.astype('category')

# %% [markdown]
# **Test:**

# %%
df_img.dtypes
# Out:
# tweet_id       int64
# jpg_url       object
# img_num     category
# p1            object
# p1_conf      float64
# p1_dog          bool
# p2            object
# p2_conf      float64
# p2_dog          bool
# p3            object
# p3_conf      float64
# p3_dog          bool
# dtype: object

# %% [markdown]
# **Define:**
#
#
# **Subtract rating_numerator from rating_denominator and create new column called rating instead of two columns.**
#
#
# **Code**

# %%
df_archives['Rating'] = df_archives.rating_numerator - df_archives.rating_denominator

# %% [markdown]
# **Test:**

# %%
df_archives.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp              source  \
# 0 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# ...

# %% [markdown]
# **Drop rating_numerator & rating_denominator:**

# %%
df_archives.drop('rating_numerator', axis = 1, inplace = True)
df_archives.drop('rating_denominator', axis = 1, inplace = True)

# %%
df_archives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2296 entries, 0 to 2355
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2296 non-null   int64
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   2296 non-null   datetime64[ns, UTC]
#  4   source                      2296 non-null   category
#  5   text                        2296 non-null   object
#  6   retweeted_status_id         179 non-null    float64
#  7   retweeted_status_user_id    179 non-null    float64
#  8   retweeted_status_timestamp  179 non-null    object
#  9   expanded_urls               2296 non-null   object
#  10  name                        1550 non-null   object
#  11  doggo                       94 non-null     object
#  12  floofer                     10 non-null     object
# ...

# %%
df_archives.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp              source  \
# 0 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# ...

# %% [markdown]
# **Define:**
#
# **Create one column for the type of the dogs and call it (type) instead of four columns:**
#
# **Code:**

# %%
df_archives['type'] = df_archives.text.str.extract('(doggo|floofer|pupper|puppo)', expand = True)
df_archives.drop(['doggo','floofer','pupper','puppo'], axis=1, inplace = True)

# %% [markdown]
# **Test:**

# %%
df_archives.type.value_counts()
# Out:
# pupper     263
# doggo       90
# puppo       34
# floofer      4
# Name: type, dtype: int64

# %% [markdown]
# **Define:**
#
# **Create master Dataframe that contains all the dataframes togther:**
#
# **Code:**

# %%
df_temp = pd.merge(df_archives, df_api, left_on = 'tweet_id', right_on = 'Tweet_id', how = 'inner')
df_master = pd.merge(df_temp, df_img, left_on = 'tweet_id', right_on = 'tweet_id', how = 'inner')

# %% [markdown]
# **Test:**

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2071 entries, 0 to 2070
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2071 non-null   int64
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   2071 non-null   datetime64[ns, UTC]
#  4   source                      2071 non-null   category
#  5   text                        2071 non-null   object
#  6   retweeted_status_id         78 non-null     float64
#  7   retweeted_status_user_id    78 non-null     float64
#  8   retweeted_status_timestamp  78 non-null     object
#  9   expanded_urls               2071 non-null   object
#  10  name                        1435 non-null   object
#  11  Rating                      2071 non-null   int64
#  12  type                        336 non-null    object
# ...

# %% [markdown]
# **Store the master dataframe into CSV file:**

# %%
df_master.to_csv('twitter_archive_master.csv', index=False)

# %% [markdown]
# <a id='Analysis'></a>
# ## 4-Analysis:

# %% [markdown]
# **Q1:What is the most popular type of dog in our dataset?**

# %%
most_popular = df_master.type.value_counts()
print(most_popular)
# Out:
# pupper     229
# doggo       75
# puppo       29
# floofer      3
# Name: type, dtype: int64

# %% [markdown]
# **Q2:What are the most image number in each tweet?**

# %%
most_source = df_master.img_num.value_counts()
most_source.plot(kind = 'pie', autopct='%.1f');
plt.title('What are the most number of images in each tweet');

# %% [markdown]
# **Q3:What are the most source of the tweets?**

# %%
most_source = df_master.source.value_counts()
most_source.plot(kind = 'bar', color='purple');
plt.xlabel('Source Of Tweet');
plt.ylabel('Number Of Tweets');
plt.title('What are the most source of the tweets');
